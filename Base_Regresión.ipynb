# %%
set.seed(0)
x = rnorm(100,3,1)
y = 5*rep(1,length(x)) - 2*x + rnorm(length(x),0,10)
plot(x,y)
reg = lm(y~x)
abline(reg,col='red')
# Out:
# plot without title

# %%
df = data.frame(x,y)
write.csv(df,'datos_regresion.csv')
